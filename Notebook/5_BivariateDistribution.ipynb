# %% [markdown]
# # Basic graphics for bivariate distribution

# %% [markdown]
# ## 1. Scatterplot
# visualize the association between two quantitative variables. How it is?
# - is Linear?
# - How is the Spread?
# - There are some Outliers?
# - There is correlation between two variables?

# %%
# LOAD DATASETS PACKAGES ###################################

library(datasets)  # Load/unload base packages manually


# PLOTS ####################################################

# Good to first check univariate distributions
hist(mtcars$wt) #weight 
hist(mtcars$mpg) #miles per gallons

# Basic X-Y plot for two quantitative variables
plot(mtcars$wt, mtcars$mpg)

# Add some options
plot(mtcars$wt, mtcars$mpg,
  pch = 19,         # Solid circle
  cex = 1.5,        # Make 150% size
  col = "#cc0000",  # Red
  main = "MPG as a Function of Weight of Cars",
  xlab = "Weight (in 1000 pounds)",
  ylab = "MPG")
# Out:
# Plot with title "Histogram of mtcars$wt"
# Plot with title "Histogram of mtcars$mpg"
# plot without title
# Plot with title "MPG as a Function of Weight of Cars"

# %% [markdown]
# What do you observe? for each car we plot their position with respect weight and miles per gallons.
# Less a car weight, more miles per gallons cand do

# %% [markdown]
# ## 2. Overlaying plots
#
# Superimposing a plot one over others to increase information on visual data.

# %%
# First lets see the histogram

# Default
hist(lynx)

# Add some options
hist(lynx,
     breaks = 14,          # "Suggests" 14 bins
     freq   = FALSE,       # Axis shows density, not freq.
     col    = "thistle1",  # Color for histogram
     main   = paste("Histogram of Annual Canadian Lynx",
                    "Trappings, 1821-1934"),
     xlab   = "Number of Lynx Trapped")

# Add a normal distribution
curve(dnorm(x, mean = mean(lynx), sd = sd(lynx)),
      col = "thistle4",  # Color of curve
      lwd = 2,           # Line width of 2 pixels
      add = TRUE)        # Superimpose on previous graph

# Add two kernel density estimators
lines(density(lynx), col = "blue", lwd = 2)
lines(density(lynx, adjust = 3), col = "purple", lwd = 2)

# Add a rug plot
rug(lynx, lwd = 2, col = "gray")
# Out:
# Plot with title "Histogram of lynx"
# Plot with title "Histogram of Annual Canadian Lynx Trappings, 1821-1934"

# %% [markdown]
#  Observe that the data are skewed!
#  A normal distribution plot on non normal data help us to shows us how far we are from normal distribution.
#
#  - dnorm is density of normal distribution
#
# it is defined by its mean and its standard deviation.
#
# Is not representative of the data. Let's use a kernel density estimators which follow the distribution of the data
#
# - lines(density) is the standard density estimator
# - adjast = avarage accross (moving avarage)

# %%
# LOAD DATA ################################################

# Annual Canadian Lynx trappings 1821-1934
?lynx
head(lynx)

# %% [markdown]
# ### check outliers on Boxplot!

# %% [markdown]
# A great number of multivariate techniques revolve
# around the computation of distances:
# ➢Distances between variables.
# ➢Distances between entities.

# %% [markdown]
# ### n.b. Let's go to distance Measures!
